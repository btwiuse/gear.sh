# %%
let a = 3.14

# %%
import { GearApi } from "https://gear-js.deno.dev/api/index.ts"

# %%
let api = await GearApi.create()

# %%
api.tx.system.remark
# Out:
# [Function: decorated] {
#   is: [Function (anonymous)],
#   meta: Type(5) [Map] {
#     "name" => [String (Text): "remark"] {
#       registry: TypeRegistry { createdAtHash: undefined },
#       createdAtHash: undefined,
#       initialU8aLength: 7,
#       isStorageFallback: undefined
#     },
#     "fields" => Type(1) [
#       Type(4) [Map] {
#         "name" => Type {
#           registry: [TypeRegistry],
#           createdAtHash: undefined,
#           initialU8aLength: 8,
#           isStorageFallback: undefined
#         },
#         "type" => Type {
#           registry: [TypeRegistry],
#           createdAtHash: undefined,
#           initialU8aLength: 1,
#           isStorageFallback: undefined
#         },
#         "typeName" => Type {
#           registry: [TypeRegistry],
#           createdAtHash: undefined,
#           initialU8aLength: 9,
#           isStorageFallback: undefined
#         },
#         "docs" => Type(0) [
#           registry: [TypeRegistry],
#           createdAtHash: undefined,
#           initialU8aLength: 1,
#           isStorageFallback: undefined
#         ],
#         registry: TypeRegistry { createdAtHash: undefined },
#         createdAtHash: undefined,
#         initialU8aLength: 0,
#         isStorageFallback: undefined
#       },
#       registry: TypeRegistry { createdAtHash: undefined },
#       createdAtHash: undefined,
#       initialU8aLength: 0,
#       isStorageFallback: undefined
#     ],
#     "index" => <BN: 0>,
#     "docs" => Type(4) [
#       [String (Text): "Make some on-chain remark."] {
#         registry: TypeRegistry { createdAtHash: undefined },
#         createdAtHash: undefined,
#         initialU8aLength: 27,
#         isStorageFallback: undefined
#       },
#       [String (Text): ""] {
#         registry: TypeRegistry { createdAtHash: undefined },
#         createdAtHash: undefined,
#         initialU8aLength: 1,
#         isStorageFallback: undefined
#       },
#       [String (Text): "## Complexity"] {
#         registry: TypeRegistry { createdAtHash: undefined },
#         createdAtHash: undefined,
#         initialU8aLength: 14,
#         isStorageFallback: undefined
#       },
#       [String (Text): "- `O(1)`"] {
#         registry: TypeRegistry { createdAtHash: undefined },
#         createdAtHash: undefined,
#         initialU8aLength: 9,
#         isStorageFallback: undefined
#       },
#       registry: TypeRegistry { createdAtHash: undefined },
#       createdAtHash: undefined,
#       initialU8aLength: 0,
#       isStorageFallback: undefined
#     ],
#     "args" => Type(1) [
#       Type(3) [Map] {
#         "name" => [String (Text): "remark"] {
#           registry: [TypeRegistry],
#           createdAtHash: undefined,
#           initialU8aLength: 0,
#           isStorageFallback: undefined
#         },
#         "type" => [String (Type): "Bytes"] {
#           registry: [TypeRegistry],
#           createdAtHash: undefined,
#           initialU8aLength: 0,
#           isStorageFallback: undefined
#         },
#         "typeName" => Type {
#           registry: [TypeRegistry],
#           createdAtHash: undefined,
#           initialU8aLength: undefined,
#           isStorageFallback: undefined
#         },
#         registry: TypeRegistry { createdAtHash: undefined },
#         createdAtHash: undefined,
#         initialU8aLength: 0,
#         isStorageFallback: undefined
#       },
#       registry: TypeRegistry { createdAtHash: undefined },
#       createdAtHash: undefined,
#       initialU8aLength: 0,
#       isStorageFallback: undefined
#     ],
#     registry: TypeRegistry { createdAtHash: undefined },
#     createdAtHash: undefined,
#     initialU8aLength: 0,
#     isStorageFallback: undefined
#   },
#   method: "remark",
#   section: "system",
#   toJSON: [Function (anonymous)],
#   callIndex: Uint8Array(2) [ 0, 0 ]
# }

# %%
console.log("powershell")
# Out:
# powershell

# %%
api
# Out:
# <ref *1> GearApi {
#   __phantom: <BN: 0>,
#   _type: "promise",
#   _call: {
#     babeApi: {
#       configuration: [Getter],
#       currentEpoch: [Getter],
#       currentEpochStart: [Getter],
#       generateKeyOwnershipProof: [Getter],
#       nextEpoch: [Getter],
#       submitReportEquivocationUnsignedExtrinsic: [Getter]
#     },
#     blockBuilder: {
#       applyExtrinsic: [Getter],
#       checkInherents: [Getter],
#       inherentExtrinsics: [Getter],
#       finalizeBlock: [Getter]
#     },
#     grandpaApi: {
#       currentSetId: [Getter],
#       generateKeyOwnershipProof: [Getter],
#       grandpaAuthorities: [Getter],
#       submitReportEquivocationUnsignedExtrinsic: [Getter]
#     },
#     metadata: { metadata: [Getter] },
#     offchainWorkerApi: { offchainWorker: [Getter] },
#     transactionPaymentApi: {
#       queryLengthToFee: [Getter],
#       queryWeightToFee: [Getter],
#       queryInfo: [Getter],
#       queryFeeDetails: [Getter]
#     },
#     core: {
#       version: [Getter],
#       executeBlock: [Getter],
#       initializeBlock: [Getter]
#     },
#     sessionKeys: { decodeSessionKeys: [Getter], generateSessionKeys: [Getter] },
#     accountNonceApi: { accountNonce: [Getter] },
#     taggedTransactionQueue: { validateTransaction: [Getter] }
#   },
#   _consts: {
#     system: {
#       blockWeights: [Getter],
#       blockLength: [Getter],
#       blockHashCount: [Getter],
#       dbWeight: [Getter],
#       version: [Getter],
#       ss58Prefix: [Getter]
#     },
#     timestamp: { minimumPeriod: [Getter] },
#     babe: {
#       epochDuration: [Getter],
#       expectedBlockTime: [Getter],
#       maxAuthorities: [Getter]
#     },
#     grandpa: { maxAuthorities: [Getter], maxSetIdSessionEntries: [Getter] },
#     balances: {
#       existentialDeposit: [Getter],
#       maxLocks: [Getter],
#       maxReserves: [Getter]
#     },
#     transactionPayment: { operationalFeeMultiplier: [Getter] },
#     utility: { batchedCallsLimit: [Getter] },
#     proxy: {
#       proxyDepositBase: [Getter],
#       proxyDepositFactor: [Getter],
#       maxProxies: [Getter],
#       maxPending: [Getter],
#       announcementDepositBase: [Getter],
#       announcementDepositFactor: [Getter]
#     },
#     multisig: {
#       depositBase: [Getter],
#       depositFactor: [Getter],
#       maxSignatories: [Getter]
#     },
#     gearScheduler: {
#       reserveThreshold: [Getter],
#       waitlistCost: [Getter],
#       mailboxCost: [Getter],
#       reservationCost: [Getter],
#       dispatchHoldCost: [Getter]
#     },
#     gearGas: { blockGasLimit: [Getter] },
#     gear: {
#       schedule: [Getter],
#       outgoingLimit: [Getter],
#       mailboxThreshold: [Getter],
#       reservationsLimit: [Getter],
#       programRentFreePeriod: [Getter],
#       programResumeMinimalRentPeriod: [Getter],
#       programRentCostPerBlock: [Getter],
#       programResumeSessionDuration: [Getter],
#       programRentEnabled: [Getter],
#       programRentDisabledDelta: [Getter]
#     },
#     gearVoucher: { palletId: [Getter] },
#     gearBank: { bankAddress: [Getter], gasMultiplier: [Getter] }
#   },
#   _derive: {
#     accounts: [Getter],
#     alliance: [Getter],
#     balances: [Getter],
#     bounties: [Getter],
#     chain: {
#       _getHeaderRange: [Getter],
#       bestNumber: [Getter],
#       bestNumberFinalized: [Getter],
#       bestNumberLag: [Getter],
#       getBlock: [Getter],
#       getBlockByNumber: [Getter],
#       getHeader: [Getter],
#       subscribeFinalizedHeads: [Getter],
#       subscribeNewBlocks: [Getter],
#       subscribeNewHeads: [Function (anonymous)]
#     },
#     session: [Getter],
#     tx: [Getter]
#   },
#   _errors: {
#     system: {
#       InvalidSpecName: [Getter],
#       SpecVersionNeedsToIncrease: [Getter],
#       FailedToExtractRuntimeVersion: [Getter],
#       NonDefaultComposite: [Getter],
#       NonZeroRefCount: [Getter],
#       CallFiltered: [Getter]
#     },
#     babe: {
#       InvalidEquivocationProof: [Getter],
#       InvalidKeyOwnershipProof: [Getter],
#       DuplicateOffenceReport: [Getter],
#       InvalidConfiguration: [Getter]
#     },
#     grandpa: {
#       PauseFailed: [Getter],
#       ResumeFailed: [Getter],
#       ChangePending: [Getter],
#       TooSoon: [Getter],
#       InvalidKeyOwnershipProof: [Getter],
#       InvalidEquivocationProof: [Getter],
#       DuplicateOffenceReport: [Getter]
#     },
#     balances: {
#       VestingBalance: [Getter],
#       LiquidityRestrictions: [Getter],
#       InsufficientBalance: [Getter],
#       ExistentialDeposit: [Getter],
#       KeepAlive: [Getter],
#       ExistingVestingSchedule: [Getter],
#       DeadAccount: [Getter],
#       TooManyReserves: [Getter]
#     },
#     session: {
#       InvalidProof: [Getter],
#       NoAssociatedValidatorId: [Getter],
#       DuplicatedKey: [Getter],
#       NoKeys: [Getter],
#       NoAccount: [Getter]
#     },
#     utility: { TooManyCalls: [Getter] },
#     proxy: {
#       TooMany: [Getter],
#       NotFound: [Getter],
#       NotProxy: [Getter],
#       Unproxyable: [Getter],
#       Duplicate: [Getter],
#       NoPermission: [Getter],
#       Unannounced: [Getter],
#       NoSelfProxy: [Getter]
#     },
#     multisig: {
#       MinimumThreshold: [Getter],
#       AlreadyApproved: [Getter],
#       NoApprovalsNeeded: [Getter],
#       TooFewSignatories: [Getter],
#       TooManySignatories: [Getter],
#       SignatoriesOutOfOrder: [Getter],
#       SenderInSignatories: [Getter],
#       NotFound: [Getter],
#       NotOwner: [Getter],
#       NoTimepoint: [Getter],
#       WrongTimepoint: [Getter],
#       UnexpectedTimepoint: [Getter],
#       MaxWeightTooLow: [Getter],
#       AlreadyStored: [Getter]
#     },
#     validatorSet: {
#       TooLowValidatorCount: [Getter],
#       Duplicate: [Getter],
#       ValidatorNotApproved: [Getter],
#       BadOrigin: [Getter]
#     },
#     sudo: { RequireSudo: [Getter] },
#     gearProgram: {
#       DuplicateItem: [Getter],
#       ProgramNotFound: [Getter],
#       NotActiveProgram: [Getter],
#       CannotFindDataForPage: [Getter],
#       ResumeSessionNotFound: [Getter],
#       NotSessionOwner: [Getter],
#       ResumeSessionFailed: [Getter],
#       ProgramCodeNotFound: [Getter],
#       DuplicateResumeSession: [Getter]
#     },
#     gearMessenger: {
#       QueueDuplicateKey: [Getter],
#       QueueElementNotFound: [Getter],
#       QueueHeadShouldBeSet: [Getter],
#       QueueHeadShouldNotBeSet: [Getter],
#       QueueTailHasNextKey: [Getter],
#       QueueTailParentNotFound: [Getter],
#       QueueTailShouldBeSet: [Getter],
#       QueueTailShouldNotBeSet: [Getter],
#       MailboxDuplicateKey: [Getter],
#       MailboxElementNotFound: [Getter],
#       WaitlistDuplicateKey: [Getter],
#       WaitlistElementNotFound: [Getter]
#     },
#     gearScheduler: { DuplicateTask: [Getter], TaskNotFound: [Getter] },
#     gearGas: {
#       Forbidden: [Getter],
#       NodeAlreadyExists: [Getter],
#       InsufficientBalance: [Getter],
#       NodeNotFound: [Getter],
#       NodeWasConsumed: [Getter],
#       ParentIsLost: [Getter],
#       ParentHasNoChildren: [Getter],
#       UnexpectedConsumeOutput: [Getter],
#       UnexpectedNodeType: [Getter],
#       ValueIsNotCaught: [Getter],
#       ValueIsBlocked: [Getter],
#       ValueIsNotBlocked: [Getter],
#       ConsumedWithLock: [Getter],
#       ConsumedWithSystemReservation: [Getter],
#       TotalValueIsOverflowed: [Getter],
#       TotalValueIsUnderflowed: [Getter]
#     },
#     gear: {
#       MessageNotFound: [Getter],
#       InsufficientBalance: [Getter],
#       GasLimitTooHigh: [Getter],
#       ProgramAlreadyExists: [Getter],
#       InactiveProgram: [Getter],
#       NoMessageTree: [Getter],
#       CodeAlreadyExists: [Getter],
#       CodeDoesntExist: [Getter],
#       CodeTooLarge: [Getter],
#       ProgramConstructionFailed: [Getter],
#       ValueLessThanMinimal: [Getter],
#       MessageQueueProcessingDisabled: [Getter],
#       ResumePeriodLessThanMinimal: [Getter],
#       ProgramNotFound: [Getter],
#       FailureRedeemingVoucher: [Getter],
#       GearRunAlreadyInBlock: [Getter],
#       ProgramRentDisabled: [Getter]
#     },
#     gearVoucher: {
#       FailureToCreateVoucher: [Getter],
#       FailureToRedeemVoucher: [Getter]
#     },
#     gearBank: {
#       InsufficientBalance: [Getter],
#       InsufficientGasBalance: [Getter],
#       InsufficientValueBalance: [Getter],
#       InsufficientBankBalance: [Getter],
#       InsufficientDeposit: [Getter]
#     },
#     gearDebug: {}
#   },
#   _events: {
#     system: {
#       ExtrinsicSuccess: [Getter],
#       ExtrinsicFailed: [Getter],
#       CodeUpdated: [Getter],
#       NewAccount: [Getter],
#       KilledAccount: [Getter],
#       Remarked: [Getter]
#     },
#     grandpa: { NewAuthorities: [Getter], Paused: [Getter], Resumed: [Getter] },
#     balances: {
#       Endowed: [Getter],
#       DustLost: [Getter],
#       Transfer: [Getter],
#       BalanceSet: [Getter],
#       Reserved: [Getter],
#       Unreserved: [Getter],
#       ReserveRepatriated: [Getter],
#       Deposit: [Getter],
#       Withdraw: [Getter],
#       Slashed: [Getter]
#     },
#     transactionPayment: { TransactionFeePaid: [Getter] },
#     session: { NewSession: [Getter] },
#     utility: {
#       BatchInterrupted: [Getter],
#       BatchCompleted: [Getter],
#       BatchCompletedWithErrors: [Getter],
#       ItemCompleted: [Getter],
#       ItemFailed: [Getter],
#       DispatchedAs: [Getter]
#     },
#     proxy: {
#       ProxyExecuted: [Getter],
#       PureCreated: [Getter],
#       Announced: [Getter],
#       ProxyAdded: [Getter],
#       ProxyRemoved: [Getter]
#     },
#     multisig: {
#       NewMultisig: [Getter],
#       MultisigApproval: [Getter],
#       MultisigExecuted: [Getter],
#       MultisigCancelled: [Getter]
#     },
#     validatorSet: {
#       ValidatorAdditionInitiated: [Getter],
#       ValidatorRemovalInitiated: [Getter]
#     },
#     sudo: { Sudid: [Getter], KeyChanged: [Getter], SudoAsDone: [Getter] },
#     gear: {
#       MessageQueued: [Getter],
#       UserMessageSent: [Getter],
#       UserMessageRead: [Getter],
#       MessagesDispatched: [Getter],
#       MessageWaited: [Getter],
#       MessageWoken: [Getter],
#       CodeChanged: [Getter],
#       ProgramChanged: [Getter],
#       QueueNotProcessed: [Getter],
#       ProgramResumeSessionStarted: [Getter]
#     },
#     gearVoucher: { VoucherIssued: [Getter] },
#     gearDebug: { DebugMode: [Getter], DebugDataSnapshot: [Getter] }
#   },
#   _extrinsics: [Function (anonymous)] {
#     system: {
#       remark: [Function: decorated] {
#         is: [Function (anonymous)],
#         meta: Type(5) [Map] {
#           "name" => [Text],
#           "fields" => [Type],
#           "index" => <BN: 0>,
#           "docs" => [Type],
#           "args" => [Type],
#           registry: [TypeRegistry],
#           createdAtHash: undefined,
#           initialU8aLength: 0,
#           isStorageFallback: undefined
#         },
#         method: "remark",
#         section: "system",
#         toJSON: [Function (anonymous)],
#         callIndex: Uint8Array(2) [ 0, 0 ]
#       },
#       setHeapPages: [Getter],
#       setCode: [Getter],
#       setCodeWithoutChecks: [Getter],
#       setStorage: [Getter],
#       killStorage: [Getter],
#       killPrefix: [Getter],
#       remarkWithEvent: [Getter]
#     },
#     timestamp: [Getter],
#     babe: [Getter],
#     grandpa: [Getter],
#     balances: [Getter],
#     session: [Getter],
#     utility: [Getter],
#     proxy: [Getter],
#     multisig: [Getter],
#     validatorSet: [Getter],
#     sudo: [Getter],
#     gear: [Getter],
#     gearVoucher: [Getter],
#     gearDebug: [Getter]
#   },
#   _extrinsicType: 4,
#   _genesisHash: Type(32) [Uint8Array] [
#     165,
#     253,
#     202,
#     221,
#     36,
#     131,
#     44,
#     112,
#     144,
#     255,
#     11,
#     11,
#     108,
#     227,
#     125,
#     96,
#     183,
#     202,
#     156,
#     181,
#     76,
#     36,
#     230,
#     186,
#     233,
#     62,
#     42,
#     23,
#     13,
#     99,
#     7,
#     199,
#     registry: TypeRegistry { createdAtHash: undefined },
#     createdAtHash: undefined,
#     initialU8aLength: 32,
#     isStorageFallback: undefined
#   ],
#   _isConnected: _e {
#     closed: false,
#     currentObservers: [],
#     observers: [],
#     isStopped: false,
#     hasError: false,
#     thrownError: null,
#     _value: true
#   },
#   _isReady: true,
#   _query: {
#     substrate: {
#       changesTrieConfig: [Getter],
#       childStorageKeyPrefix: [Getter],
#       code: [Getter],
#       extrinsicIndex: [Getter],
#       heapPages: [Getter]
#     },
#     system: {
#       palletVersion: [Getter],
#       account: [Getter],
#       extrinsicCount: [Getter],
#       blockWeight: [Getter],
#       allExtrinsicsLen: [Getter],
#       blockHash: [Getter],
#       extrinsicData: [Getter],
#       number: [Getter],
#       parentHash: [Getter],
#       digest: [Getter],
#       events: [Getter],
#       eventCount: [Getter],
#       eventTopics: [Getter],
#       lastRuntimeUpgrade: [Getter],
#       upgradedToU32RefCount: [Getter],
#       upgradedToTripleRefCount: [Getter],
#       executionPhase: [Getter]
#     },
#     timestamp: { palletVersion: [Getter], now: [Getter], didUpdate: [Getter] },
#     authorship: { palletVersion: [Getter], author: [Getter] },
#     babe: {
#       palletVersion: [Getter],
#       epochIndex: [Getter],
#       authorities: [Getter],
#       genesisSlot: [Getter],
#       currentSlot: [Getter],
#       randomness: [Getter],
#       pendingEpochConfigChange: [Getter],
#       nextRandomness: [Getter],
#       nextAuthorities: [Getter],
#       segmentIndex: [Getter],
#       underConstruction: [Getter],
#       initialized: [Getter],
#       authorVrfRandomness: [Getter],
#       epochStart: [Getter],
#       lateness: [Getter],
#       epochConfig: [Getter],
#       nextEpochConfig: [Getter],
#       skippedEpochs: [Getter]
#     },
#     grandpa: {
#       palletVersion: [Getter],
#       state: [Getter],
#       pendingChange: [Getter],
#       nextForced: [Getter],
#       stalled: [Getter],
#       currentSetId: [Getter],
#       setIdSession: [Getter]
#     },
#     balances: {
#       palletVersion: [Getter],
#       totalIssuance: [Getter],
#       inactiveIssuance: [Getter],
#       account: [Getter],
#       locks: [Getter],
#       reserves: [Getter]
#     },
#     transactionPayment: {
#       palletVersion: [Getter],
#       nextFeeMultiplier: [Getter],
#       storageVersion: [Getter]
#     },
#     session: {
#       palletVersion: [Getter],
#       validators: [Getter],
#       currentIndex: [Getter],
#       queuedChanged: [Getter],
#       queuedKeys: [Getter],
#       disabledValidators: [Getter],
#       nextKeys: [Getter],
#       keyOwner: [Getter]
#     },
#     proxy: {
#       palletVersion: [Getter],
#       proxies: [Getter],
#       announcements: [Getter]
#     },
#     multisig: { palletVersion: [Getter], multisigs: [Getter] },
#     validatorSet: {
#       palletVersion: [Getter],
#       validators: [Getter],
#       approvedValidators: [Getter],
#       offlineValidators: [Getter]
#     },
#     sudo: { palletVersion: [Getter], key: [Getter] },
#     gearProgram: {
#       palletVersion: [Getter],
#       codeStorage: [Getter],
#       codeLenStorage: [Getter],
#       originalCodeStorage: [Getter],
#       metadataStorage: [Getter],
#       programStorage: [Getter],
#       memoryPageStorage: [Getter],
#       waitingInitStorage: [Getter],
#       pausedProgramStorage: [Getter],
#       resumeSessionsNonce: [Getter],
#       resumeSessions: [Getter],
#       sessionMemoryPages: [Getter]
#     },
#     gearMessenger: {
#       palletVersion: [Getter],
#       dequeued: [Getter],
#       dispatches: [Getter],
#       counterForDispatches: [Getter],
#       head: [Getter],
#       mailbox: [Getter],
#       queueProcessing: [Getter],
#       sent: [Getter],
#       tail: [Getter],
#       waitlist: [Getter],
#       dispatchStash: [Getter]
#     },
#     gearScheduler: {
#       palletVersion: [Getter],
#       firstIncompleteTasksBlock: [Getter],
#       taskPool: [Getter]
#     },
#     gearGas: {
#       palletVersion: [Getter],
#       totalIssuance: [Getter],
#       gasNodes: [Getter],
#       allowance: [Getter]
#     },
#     gear: {
#       palletVersion: [Getter],
#       executeInherent: [Getter],
#       blockNumber: [Getter],
#       gearRunInBlock: [Getter]
#     },
#     gearBank: { palletVersion: [Getter], bank: [Getter], unusedValue: [Getter] },
#     gearDebug: {
#       palletVersion: [Getter],
#       debugMode: [Getter],
#       remapId: [Getter],
#       programsMap: [Getter]
#     }
#   },
#   _queryMulti: [Function (anonymous)],
#   _rpc: [Function (anonymous)] {
#     author: {
#       hasKey: [Getter],
#       hasSessionKeys: [Getter],
#       insertKey: [Getter],
#       pendingExtrinsics: [Getter],
#       removeExtrinsic: [Getter],
#       rotateKeys: [Getter],
#       submitAndWatchExtrinsic: [Getter],
#       submitExtrinsic: [Getter]
#     },
#     babe: { epochAuthorship: [Getter] },
#     beefy: {},
#     chain: {
#       getBlock: [Getter],
#       getBlockHash: [Getter],
#       getFinalizedHead: [Getter],
#       getHeader: [Getter],
#       subscribeAllHeads: [Getter],
#       subscribeFinalizedHeads: [Getter],
#       subscribeNewHeads: [Getter]
#     },
#     childstate: {
#       getKeys: [Getter],
#       getKeysPaged: [Getter],
#       getStorage: [Getter],
#       getStorageEntries: [Getter],
#       getStorageHash: [Getter],
#       getStorageSize: [Getter]
#     },
#     contracts: {},
#     dev: { getBlockStats: [Getter] },
#     engine: {},
#     net: {},
#     web3: {},
#     eth: {},
#     grandpa: {
#       proveFinality: [Getter],
#       roundState: [Getter],
#       subscribeJustifications: [Getter]
#     },
#     mmr: {},
#     offchain: { localStorageGet: [Getter], localStorageSet: [Getter] },
#     payment: { queryFeeDetails: [Getter], queryInfo: [Getter] },
#     rpc: { methods: [Getter] },
#     state: {
#       call: [Getter],
#       getChildReadProof: [Getter],
#       getKeys: [Getter],
#       getKeysPaged: [Getter],
#       getMetadata: [Getter],
#       getPairs: [Getter],
#       getReadProof: [Getter],
#       getRuntimeVersion: [Getter],
#       getStorage: [Getter],
#       getStorageHash: [Getter],
#       getStorageSize: [Getter],
#       queryStorage: [Getter],
#       queryStorageAt: [Getter],
#       subscribeRuntimeVersion: [Getter],
#       subscribeStorage: [Getter],
#       traceBlock: [Getter],
#       trieMigrationStatus: [Getter]
#     },
#     syncstate: { genSyncSpec: [Getter] },
#     system: {
#       accountNextIndex: [Getter],
#       addLogFilter: [Getter],
#       addReservedPeer: [Getter],
#       chain: [Getter],
#       chainType: [Getter],
#       dryRun: [Getter],
#       health: [Getter],
#       localListenAddresses: [Getter],
#       localPeerId: [Getter],
#       name: [Getter],
#       nodeRoles: [Getter],
#       peers: [Getter],
#       properties: [Getter],
#       removeReservedPeer: [Getter],
#       reservedPeers: [Getter],
#       resetLogFilter: [Getter],
#       syncState: [Getter],
#       version: [Getter]
#     },
#     gear: {
#       calculateInitUploadGas: [Getter],
#       calculateInitCreateGas: [Getter],
#       calculateHandleGas: [Getter],
#       calculateReplyGas: [Getter],
#       readMetahash: [Getter],
#       readState: [Getter],
#       readStateUsingWasm: [Getter],
#       readStateBatch: [Getter],
#       readStateUsingWasmBatch: [Getter]
#     },
#     chainSpec_unstable: {
#       chainName: [Getter],
#       properties: [Getter],
#       genesisHash: [Getter]
#     },
#     transaction_unstable: { submitAndWatch: [Getter], unwatch: [Getter] },
#     runtime: { wasmBlobVersion: [Getter] }
#   },
#   _rpcCore: RpcCore {
#     mapping: Map(148) {
#       "author_hasKey" => {
#         description: "Returns true if the keystore has private keys for the given public key and key type.",
#         isUnsafe: true,
#         params: [ [Object], [Object] ],
#         type: "bool",
#         isSubscription: false,
#         jsonrpc: "author_hasKey",
#         method: "hasKey",
#         section: "author"
#       },
#       "author_hasSessionKeys" => {
#         description: "Returns true if the keystore has private keys for the given session public keys.",
#         isUnsafe: true,
#         params: [ [Object] ],
#         type: "bool",
#         isSubscription: false,
#         jsonrpc: "author_hasSessionKeys",
#         method: "hasSessionKeys",
#         section: "author"
#       },
#       "author_insertKey" => {
#         description: "Insert a key into the keystore.",
#         isUnsafe: true,
#         params: [ [Object], [Object], [Object] ],
#         type: "Bytes",
#         isSubscription: false,
#         jsonrpc: "author_insertKey",
#         method: "insertKey",
#         section: "author"
#       },
#       "author_pendingExtrinsics" => {
#         description: "Returns all pending extrinsics, potentially grouped by sender",
#         params: [],
#         type: "Vec<Extrinsic>",
#         isSubscription: false,
#         jsonrpc: "author_pendingExtrinsics",
#         method: "pendingExtrinsics",
#         section: "author"
#       },
#       "author_removeExtrinsic" => {
#         description: "Remove given extrinsic from the pool and temporarily ban it to prevent reimporting",
#         isUnsafe: true,
#         params: [ [Object] ],
#         type: "Vec<Hash>",
#         isSubscription: false,
#         jsonrpc: "author_removeExtrinsic",
#         method: "removeExtrinsic",
#         section: "author"
#       },
#       "author_rotateKeys" => {
#         description: "Generate new session keys and returns the corresponding public keys",
#         isUnsafe: true,
#         params: [],
#         type: "Bytes",
#         isSubscription: false,
#         jsonrpc: "author_rotateKeys",
#         method: "rotateKeys",
#         section: "author"
#       },
#       "author_submitAndWatchExtrinsic" => {
#         description: "Submit and subscribe to watch an extrinsic until unsubscribed",
#         isSigned: true,
#         params: [ [Object] ],
#         pubsub: [
#           "extrinsicUpdate",
#           "submitAndWatchExtrinsic",
#           "unwatchExtrinsic"
#         ],
#         type: "ExtrinsicStatus",
#         isSubscription: true,
#         jsonrpc: "author_submitAndWatchExtrinsic",
#         method: "submitAndWatchExtrinsic",
#         section: "author"
#       },
#       "author_submitExtrinsic" => {
#         description: "Submit a fully formatted extrinsic for block inclusion",
#         isSigned: true,
#         params: [ [Object] ],
#         type: "Hash",
#         isSubscription: false,
#         jsonrpc: "author_submitExtrinsic",
#         method: "submitExtrinsic",
#         section: "author"
#       },
#       "babe_epochAuthorship" => {
#         description: "Returns data about which slots (primary or secondary) can be claimed in the current epoch with the k"... 19 more characters,
#         isUnsafe: true,
#         params: [],
#         type: "HashMap<AuthorityId, EpochAuthorship>",
#         isSubscription: false,
#         jsonrpc: "babe_epochAuthorship",
#         method: "epochAuthorship",
#         section: "babe"
#       },
#       "beefy_getFinalizedHead" => {
#         description: "Returns hash of the latest BEEFY finalized block as seen by this client.",
#         params: [],
#         type: "H256",
#         isSubscription: false,
#         jsonrpc: "beefy_getFinalizedHead",
#         method: "getFinalizedHead",
#         section: "beefy"
#       },
#       "beefy_subscribeJustifications" => {
#         description: "Returns the block most recently finalized by BEEFY, alongside side its justification.",
#         params: [],
#         pubsub: [
#           "justifications",
#           "subscribeJustifications",
#           "unsubscribeJustifications"
#         ],
#         type: "BeefySignedCommitment",
#         isSubscription: true,
#         jsonrpc: "beefy_subscribeJustifications",
#         method: "subscribeJustifications",
#         section: "beefy"
#       },
#       "chain_getBlock" => {
#         description: "Get header and body of a relay chain block",
#         params: [ [Object] ],
#         type: "SignedBlock",
#         isSubscription: false,
#         jsonrpc: "chain_getBlock",
#         method: "getBlock",
#         section: "chain"
#       },
#       "chain_getBlockHash" => {
#         description: "Get the block hash for a specific block",
#         params: [ [Object] ],
#         type: "BlockHash",
#         isSubscription: false,
#         jsonrpc: "chain_getBlockHash",
#         method: "getBlockHash",
#         section: "chain"
#       },
#       "chain_getFinalizedHead" => {
#         alias: [ "chain_getFinalisedHead" ],
#         description: "Get hash of the last finalized block in the canon chain",
#         params: [],
#         type: "BlockHash",
#         isSubscription: false,
#         jsonrpc: "chain_getFinalizedHead",
#         method: "getFinalizedHead",
#         section: "chain"
#       },
#       "chain_getHeader" => {
#         alias: [ "chain_getHead" ],
#         description: "Retrieves the header for a specific block",
#         params: [ [Object] ],
#         type: "Header",
#         isSubscription: false,
#         jsonrpc: "chain_getHeader",
#         method: "getHeader",
#         section: "chain"
#       },
#       "chain_subscribeAllHeads" => {
#         description: "Retrieves the newest header via subscription",
#         params: [],
#         pubsub: [ "allHead", "subscribeAllHeads", "unsubscribeAllHeads" ],
#         type: "Header",
#         isSubscription: true,
#         jsonrpc: "chain_subscribeAllHeads",
#         method: "subscribeAllHeads",
#         section: "chain"
#       },
#       "chain_subscribeFinalizedHeads" => {
#         alias: [
#           "chain_subscribeFinalisedHeads",
#           "chain_unsubscribeFinalisedHeads"
#         ],
#         description: "Retrieves the best finalized header via subscription",
#         params: [],
#         pubsub: [
#           "finalizedHead",
#           "subscribeFinalizedHeads",
#           "unsubscribeFinalizedHeads"
#         ],
#         type: "Header",
#         isSubscription: true,
#         jsonrpc: "chain_subscribeFinalizedHeads",
#         method: "subscribeFinalizedHeads",
#         section: "chain"
#       },
#       "chain_subscribeNewHeads" => {
#         alias: [
#           "chain_unsubscribeNewHeads",
#           "subscribe_newHead",
#           "unsubscribe_newHead"
#         ],
#         description: "Retrieves the best header via subscription",
#         params: [],
#         pubsub: [ "newHead", "subscribeNewHead", "unsubscribeNewHead" ],
#         type: "Header",
#         isSubscription: true,
#         jsonrpc: "chain_subscribeNewHeads",
#         method: "subscribeNewHeads",
#         section: "chain"
#       },
#       "childstate_getKeys" => {
#         description: "Returns the keys with prefix from a child storage, leave empty to get all the keys",
#         params: [ [Object], [Object], [Object] ],
#         type: "Vec<StorageKey>",
#         isSubscription: false,
#         jsonrpc: "childstate_getKeys",
#         method: "getKeys",
#         section: "childstate"
#       },
#       "childstate_getKeysPaged" => {
#         alias: [ "childstate_getKeysPagedAt" ],
#         description: "Returns the keys with prefix from a child storage with pagination support",
#         params: [ [Object], [Object], [Object], [Object], [Object] ],
#         type: "Vec<StorageKey>",
#         isSubscription: false,
#         jsonrpc: "childstate_getKeysPaged",
#         method: "getKeysPaged",
#         section: "childstate"
#       },
#       "childstate_getStorage" => {
#         description: "Returns a child storage entry at a specific block state",
#         params: [ [Object], [Object], [Object] ],
#         type: "Option<StorageData>",
#         isSubscription: false,
#         jsonrpc: "childstate_getStorage",
#         method: "getStorage",
#         section: "childstate"
#       },
#       "childstate_getStorageEntries" => {
#         description: "Returns child storage entries for multiple keys at a specific block state",
#         params: [ [Object], [Object], [Object] ],
#         type: "Vec<Option<StorageData>>",
#         isSubscription: false,
#         jsonrpc: "childstate_getStorageEntries",
#         method: "getStorageEntries",
#         section: "childstate"
#       },
#       "childstate_getStorageHash" => {
#         description: "Returns the hash of a child storage entry at a block state",
#         params: [ [Object], [Object], [Object] ],
#         type: "Option<Hash>",
#         isSubscription: false,
#         jsonrpc: "childstate_getStorageHash",
#         method: "getStorageHash",
#         section: "childstate"
#       },
#       "childstate_getStorageSize" => {
#         description: "Returns the size of a child storage entry at a block state",
#         params: [ [Object], [Object], [Object] ],
#         type: "Option<u64>",
#         isSubscription: false,
#         jsonrpc: "childstate_getStorageSize",
#         method: "getStorageSize",
#         section: "childstate"
#       },
#       "contracts_call" => {
#         deprecated: "Use the runtime interface `api.call.contractsApi.call` instead",
#         description: "Executes a call to a contract",
#         params: [ [Object], [Object] ],
#         type: "ContractExecResult",
#         isSubscription: false,
#         jsonrpc: "contracts_call",
#         method: "call",
#         section: "contracts"
#       },
#       "contracts_getStorage" => {
#         deprecated: "Use the runtime interface `api.call.contractsApi.getStorage` instead",
#         description: "Returns the value under a specified storage key in a contract",
#         params: [ [Object], [Object], [Object] ],
#         type: "Option<Bytes>",
#         isSubscription: false,
#         jsonrpc: "contracts_getStorage",
#         method: "getStorage",
#         section: "contracts"
#       },
#       "contracts_instantiate" => {
#         deprecated: "Use the runtime interface `api.call.contractsApi.instantiate` instead",
#         description: "Instantiate a new contract",
#         params: [ [Object], [Object] ],
#         type: "ContractInstantiateResult",
#         isSubscription: false,
#         jsonrpc: "contracts_instantiate",
#         method: "instantiate",
#         section: "contracts"
#       },
#       "contracts_rentProjection" => {
#         deprecated: "Not available in newer versions of the contracts interfaces",
#         description: "Returns the projected time a given contract will be able to sustain paying its rent",
#         params: [ [Object], [Object] ],
#         type: "Option<BlockNumber>",
#         isSubscription: false,
#         jsonrpc: "contracts_rentProjection",
#         method: "rentProjection",
#         section: "contracts"
#       },
#       "contracts_upload_code" => {
#         deprecated: "Use the runtime interface `api.call.contractsApi.uploadCode` instead",
#         description: "Upload new code without instantiating a contract from it",
#         endpoint: "contracts_upload_code",
#         params: [ [Object], [Object] ],
#         type: "CodeUploadResult",
#         isSubscription: false,
#         jsonrpc: "contracts_upload_code",
#         method: "uploadCode",
#         section: "contracts"
#       },
#       "dev_getBlockStats" => {
#         description: "Reexecute the specified `block_hash` and gather statistics while doing so",
#         isUnsafe: true,
#         params: [ [Object] ],
#         type: "Option<BlockStats>",
#         isSubscription: false,
#         jsonrpc: "dev_getBlockStats",
#         method: "getBlockStats",
#         section: "dev"
#       },
#       "engine_createBlock" => {
#         description: "Instructs the manual-seal authorship task to create a new block",
#         params: [ [Object], [Object], [Object] ],
#         type: "CreatedBlock",
#         isSubscription: false,
#         jsonrpc: "engine_createBlock",
#         method: "createBlock",
#         section: "engine"
#       },
#       "engine_finalizeBlock" => {
#         description: "Instructs the manual-seal authorship task to finalize a block",
#         params: [ [Object], [Object] ],
#         type: "bool",
#         isSubscription: false,
#         jsonrpc: "engine_finalizeBlock",
#         method: "finalizeBlock",
#         section: "engine"
#       },
#       "net_listening" => {
#         aliasSection: "net",
#         description: "Returns true if client is actively listening for network connections. Otherwise false.",
#         params: [],
#         type: "bool",
#         isSubscription: false,
#         jsonrpc: "net_listening",
#         method: "listening",
#         section: "net"
#       },
#       "net_peerCount" => {
#         aliasSection: "net",
#         description: "Returns number of peers connected to node.",
#         params: [],
#         type: "Text",
#         isSubscription: false,
#         jsonrpc: "net_peerCount",
#         method: "peerCount",
#         section: "net"
#       },
#       "net_version" => {
#         aliasSection: "net",
#         description: "Returns protocol version.",
#         params: [],
#         type: "Text",
#         isSubscription: false,
#         jsonrpc: "net_version",
#         method: "version",
#         section: "net"
#       },
#       "web3_clientVersion" => {
#         aliasSection: "web3",
#         description: "Returns current client version.",
#         params: [],
#         type: "Text",
#         isSubscription: false,
#         jsonrpc: "web3_clientVersion",
#         method: "clientVersion",
#         section: "web3"
#       },
#       "web3_sha3" => {
#         aliasSection: "web3",
#         description: "Returns sha3 of the given data",
#         params: [ [Object] ],
#         type: "H256",
#         isSubscription: false,
#         jsonrpc: "web3_sha3",
#         method: "sha3",
#         section: "web3"
#       },
#       "eth_accounts" => {
#         description: "Returns accounts list.",
#         params: [],
#         type: "Vec<H160>",
#         isSubscription: false,
#         jsonrpc: "eth_accounts",
#         method: "accounts",
#         section: "eth"
#       },
#       "eth_blockNumber" => {
#         description: "Returns the blockNumber",
#         params: [],
#         type: "U256",
#         isSubscription: false,
#         jsonrpc: "eth_blockNumber",
#         method: "blockNumber",
#         section: "eth"
#       },
#       "eth_call" => {
#         description: "Call contract, returning the output data.",
#         params: [ [Object], [Object] ],
#         type: "Bytes",
#         isSubscription: false,
#         jsonrpc: "eth_call",
#         method: "call",
#         section: "eth"
#       },
#       "eth_chainId" => {
#         description: "Returns the chain ID used for transaction signing at the current best block. None is returned if not"... 11 more characters,
#         params: [],
#         type: "U64",
#         isSubscription: false,
#         jsonrpc: "eth_chainId",
#         method: "chainId",
#         section: "eth"
#       },
#       "eth_coinbase" => {
#         description: "Returns block author.",
#         params: [],
#         type: "H160",
#         isSubscription: false,
#         jsonrpc: "eth_coinbase",
#         method: "coinbase",
#         section: "eth"
#       },
#       "eth_estimateGas" => {
#         description: "Estimate gas needed for execution of given contract.",
#         params: [ [Object], [Object] ],
#         type: "U256",
#         isSubscription: false,
#         jsonrpc: "eth_estimateGas",
#         method: "estimateGas",
#         section: "eth"
#       },
#       "eth_feeHistory" => {
#         description: "Returns fee history for given block count & reward percentiles",
#         params: [ [Object], [Object], [Object] ],
#         type: "EthFeeHistory",
#         isSubscription: false,
#         jsonrpc: "eth_feeHistory",
#         method: "feeHistory",
#         section: "eth"
#       },
#       "eth_gasPrice" => {
#         description: "Returns current gas price.",
#         params: [],
#         type: "U256",
#         isSubscription: false,
#         jsonrpc: "eth_gasPrice",
#         method: "gasPrice",
#         section: "eth"
#       },
#       "eth_getBalance" => {
#         description: "Returns balance of the given account.",
#         params: [ [Object], [Object] ],
#         type: "U256",
#         isSubscription: false,
#         jsonrpc: "eth_getBalance",
#         method: "getBalance",
#         section: "eth"
#       },
#       "eth_getBlockByHash" => {
#         description: "Returns block with given hash.",
#         params: [ [Object], [Object] ],
#         type: "Option<EthRichBlock>",
#         isSubscription: false,
#         jsonrpc: "eth_getBlockByHash",
#         method: "getBlockByHash",
#         section: "eth"
#       },
#       "eth_getBlockByNumber" => {
#         description: "Returns block with given number.",
#         params: [ [Object], [Object] ],
#         type: "Option<EthRichBlock>",
#         isSubscription: false,
#         jsonrpc: "eth_getBlockByNumber",
#         method: "getBlockByNumber",
#         section: "eth"
#       },
#       "eth_getBlockTransactionCountByHash" => {
#         description: "Returns the number of transactions in a block with given hash.",
#         params: [ [Object] ],
#         type: "U256",
#         isSubscription: false,
#         jsonrpc: "eth_getBlockTransactionCountByHash",
#         method: "getBlockTransactionCountByHash",
#         section: "eth"
#       },
#       "eth_getBlockTransactionCountByNumber" => {
#         description: "Returns the number of transactions in a block with given block number.",
#         params: [ [Object] ],
#         type: "U256",
#         isSubscription: false,
#         jsonrpc: "eth_getBlockTransactionCountByNumber",
#         method: "getBlockTransactionCountByNumber",
#         section: "eth"
#       },
#       "eth_getCode" => {
#         description: "Returns the code at given address at given time (block number).",
#         params: [ [Object], [Object] ],
#         type: "Bytes",
#         isSubscription: false,
#         jsonrpc: "eth_getCode",
#         method: "getCode",
#         section: "eth"
#       },
#       "eth_getFilterChanges" => {
#         description: "Returns filter changes since last poll.",
#         params: [ [Object] ],
#         type: "EthFilterChanges",
#         isSubscription: false,
#         jsonrpc: "eth_getFilterChanges",
#         method: "getFilterChanges",
#         section: "eth"
#       },
#       "eth_getFilterLogs" => {
#         description: "Returns all logs matching given filter (in a range 'from' - 'to').",
#         params: [ [Object] ],
#         type: "Vec<EthLog>",
#         isSubscription: false,
#         jsonrpc: "eth_getFilterLogs",
#         method: "getFilterLogs",
#         section: "eth"
#       },
#       "eth_getLogs" => {
#         description: "Returns logs matching given filter object.",
#         params: [ [Object] ],
#         type: "Vec<EthLog>",
#         isSubscription: false,
#         jsonrpc: "eth_getLogs",
#         method: "getLogs",
#         section: "eth"
#       },
#       "eth_getProof" => {
#         description: "Returns proof for account and storage.",
#         params: [ [Object], [Object], [Object] ],
#         type: "EthAccount",
#         isSubscription: false,
#         jsonrpc: "eth_getProof",
#         method: "getProof",
#         section: "eth"
#       },
#       "eth_getStorageAt" => {
#         description: "Returns content of the storage at given address.",
#         params: [ [Object], [Object], [Object] ],
#         type: "H256",
#         isSubscription: false,
#         jsonrpc: "eth_getStorageAt",
#         method: "getStorageAt",
#         section: "eth"
#       },
#       "eth_getTransactionByBlockHashAndIndex" => {
#         description: "Returns transaction at given block hash and index.",
#         params: [ [Object], [Object] ],
#         type: "EthTransaction",
#         isSubscription: false,
#         jsonrpc: "eth_getTransactionByBlockHashAndIndex",
#         method: "getTransactionByBlockHashAndIndex",
#         section: "eth"
#       },
#       "eth_getTransactionByBlockNumberAndIndex" => {
#         description: "Returns transaction by given block number and index.",
#         params: [ [Object], [Object] ],
#         type: "EthTransaction",
#         isSubscription: false,
#         jsonrpc: "eth_getTransactionByBlockNumberAndIndex",
#         method: "getTransactionByBlockNumberAndIndex",
#         section: "eth"
#       },
#       "eth_getTransactionByHash" => {
#         description: "Get transaction by its hash.",
#         params: [ [Object] ],
#         type: "EthTransaction",
#         isSubscription: false,
#         jsonrpc: "eth_getTransactionByHash",
#         method: "getTransactionByHash",
#         section: "eth"
#       },
#       "eth_getTransactionCount" => {
#         description: "Returns the number of transactions sent from given address at given time (block number).",
#         params: [ [Object], [Object] ],
#         type: "U256",
#         isSubscription: false,
#         jsonrpc: "eth_getTransactionCount",
#         method: "getTransactionCount",
#         section: "eth"
#       },
#       "eth_getTransactionReceipt" => {
#         description: "Returns transaction receipt by transaction hash.",
#         params: [ [Object] ],
#         type: "EthReceipt",
#         isSubscription: false,
#         jsonrpc: "eth_getTransactionReceipt",
#         method: "getTransactionReceipt",
#         section: "eth"
#       },
#       "eth_getUncleByBlockHashAndIndex" => {
#         description: "Returns an uncles at given block and index.",
#         params: [ [Object], [Object] ],
#         type: "EthRichBlock",
#         isSubscription: false,
#         jsonrpc: "eth_getUncleByBlockHashAndIndex",
#         method: "getUncleByBlockHashAndIndex",
#         section: "eth"
#       },
#       "eth_getUncleByBlockNumberAndIndex" => {
#         description: "Returns an uncles at given block and index.",
#         params: [ [Object], [Object] ],
#         type: "EthRichBlock",
#         isSubscription: false,
#         jsonrpc: "eth_getUncleByBlockNumberAndIndex",
#         method: "getUncleByBlockNumberAndIndex",
#         section: "eth"
#       },
#       "eth_getUncleCountByBlockHash" => {
#         description: "Returns the number of uncles in a block with given hash.",
#         params: [ [Object] ],
#         type: "U256",
#         isSubscription: false,
#         jsonrpc: "eth_getUncleCountByBlockHash",
#         method: "getUncleCountByBlockHash",
#         section: "eth"
#       },
#       "eth_getUncleCountByBlockNumber" => {
#         description: "Returns the number of uncles in a block with given block number.",
#         params: [ [Object] ],
#         type: "U256",
#         isSubscription: false,
#         jsonrpc: "eth_getUncleCountByBlockNumber",
#         method: "getUncleCountByBlockNumber",
#         section: "eth"
#       },
#       "eth_getWork" => {
#         description: "Returns the hash of the current block, the seedHash, and the boundary condition to be met.",
#         params: [],
#         type: "EthWork",
#         isSubscription: false,
#         jsonrpc: "eth_getWork",
#         method: "getWork",
#         section: "eth"
#       },
#       "eth_hashrate" => {
#         description: "Returns the number of hashes per second that the node is mining with.",
#         params: [],
#         type: "U256",
#         isSubscription: false,
#         jsonrpc: "eth_hashrate",
#         method: "hashrate",
#         section: "eth"
#       },
#       "eth_maxPriorityFeePerGas" => {
#         description: "Returns max priority fee per gas",
#         params: [],
#         type: "U256",
#         isSubscription: false,
#         jsonrpc: "eth_maxPriorityFeePerGas",
#         method: "maxPriorityFeePerGas",
#         section: "eth"
#       },
#       "eth_mining" => {
#         description: "Returns true if client is actively mining new blocks.",
#         params: [],
#         type: "bool",
#         isSubscription: false,
#         jsonrpc: "eth_mining",
#         method: "mining",
#         section: "eth"
#       },
#       "eth_newBlockFilter" => {
#         description: "Returns id of new block filter.",
#         params: [],
#         type: "U256",
#         isSubscription: false,
#         jsonrpc: "eth_newBlockFilter",
#         method: "newBlockFilter",
#         section: "eth"
#       },
#       "eth_newFilter" => {
#         description: "Returns id of new filter.",
#         params: [ [Object] ],
#         type: "U256",
#         isSubscription: false,
#         jsonrpc: "eth_newFilter",
#         method: "newFilter",
#         section: "eth"
#       },
#       "eth_newPendingTransactionFilter" => {
#         description: "Returns id of new block filter.",
#         params: [],
#         type: "U256",
#         isSubscription: false,
#         jsonrpc: "eth_newPendingTransactionFilter",
#         method: "newPendingTransactionFilter",
#         section: "eth"
#       },
#       "eth_protocolVersion" => {
#         description: "Returns protocol version encoded as a string (quotes are necessary).",
#         params: [],
#         type: "u64",
#         isSubscription: false,
#         jsonrpc: "eth_protocolVersion",
#         method: "protocolVersion",
#         section: "eth"
#       },
#       "eth_sendRawTransaction" => {
#         description: "Sends signed transaction, returning its hash.",
#         params: [ [Object] ],
#         type: "H256",
#         isSubscription: false,
#         jsonrpc: "eth_sendRawTransaction",
#         method: "sendRawTransaction",
#         section: "eth"
#       },
#       "eth_sendTransaction" => {
#         description: "Sends transaction; will block waiting for signer to return the transaction hash",
#         params: [ [Object] ],
#         type: "H256",
#         isSubscription: false,
#         jsonrpc: "eth_sendTransaction",
#         method: "sendTransaction",
#         section: "eth"
#       },
#       "eth_submitHashrate" => {
#         description: "Used for submitting mining hashrate.",
#         params: [ [Object], [Object] ],
#         type: "bool",
#         isSubscription: false,
#         jsonrpc: "eth_submitHashrate",
#         method: "submitHashrate",
#         section: "eth"
#       },
#       "eth_submitWork" => {
#         description: "Used for submitting a proof-of-work solution.",
#         params: [ [Object], [Object], [Object] ],
#         type: "bool",
#         isSubscription: false,
#         jsonrpc: "eth_submitWork",
#         method: "submitWork",
#         section: "eth"
#       },
#       "eth_subscribe" => {
#         description: "Subscribe to Eth subscription.",
#         params: [ [Object], [Object] ],
#         pubsub: [ "subscription", "subscribe", "unsubscribe" ],
#         type: "Null",
#         isSubscription: true,
#         jsonrpc: "eth_subscribe",
#         method: "subscribe",
#         section: "eth"
#       },
#       "eth_syncing" => {
#         description: "Returns an object with data about the sync status or false.",
#         params: [],
#         type: "EthSyncStatus",
#         isSubscription: false,
#         jsonrpc: "eth_syncing",
#         method: "syncing",
#         section: "eth"
#       },
#       "eth_uninstallFilter" => {
#         description: "Uninstalls filter.",
#         params: [ [Object] ],
#         type: "bool",
#         isSubscription: false,
#         jsonrpc: "eth_uninstallFilter",
#         method: "uninstallFilter",
#         section: "eth"
#       },
#       "grandpa_proveFinality" => {
#         description: "Prove finality for the given block number, returning the Justification for the last block in the set"... 1 more character,
#         params: [ [Object] ],
#         type: "Option<EncodedFinalityProofs>",
#         isSubscription: false,
#         jsonrpc: "grandpa_proveFinality",
#         method: "proveFinality",
#         section: "grandpa"
#       },
#       "grandpa_roundState" => {
#         description: "Returns the state of the current best round state as well as the ongoing background rounds",
#         params: [],
#         type: "ReportedRoundStates",
#         isSubscription: false,
#         jsonrpc: "grandpa_roundState",
#         method: "roundState",
#         section: "grandpa"
#       },
#       "grandpa_subscribeJustifications" => {
#         description: "Subscribes to grandpa justifications",
#         params: [],
#         pubsub: [
#           "justifications",
#           "subscribeJustifications",
#           "unsubscribeJustifications"
#         ],
#         type: "JustificationNotification",
#         isSubscription: true,
#         jsonrpc: "grandpa_subscribeJustifications",
#         method: "subscribeJustifications",
#         section: "grandpa"
#       },
#       "mmr_generateProof" => {
#         description: "Generate MMR proof for the given block numbers.",
#         params: [ [Object], [Object], [Object] ],
#         type: "MmrLeafBatchProof",
#         isSubscription: false,
#         jsonrpc: "mmr_generateProof",
#         method: "generateProof",
#         section: "mmr"
#       },
#       "mmr_root" => {
#         description: "Get the MMR root hash for the current best block.",
#         params: [ [Object] ],
#         type: "MmrHash",
#         isSubscription: false,
#         jsonrpc: "mmr_root",
#         method: "root",
#         section: "mmr"
#       },
#       "mmr_verifyProof" => {
#         description: "Verify an MMR proof",
#         params: [ [Object] ],
#         type: "bool",
#         isSubscription: false,
#         jsonrpc: "mmr_verifyProof",
#         method: "verifyProof",
#         section: "mmr"
#       },
#       "mmr_verifyProofStateless" => {
#         description: "Verify an MMR proof statelessly given an mmr_root",
#         params: [ [Object], [Object] ],
#         type: "bool",
#         isSubscription: false,
#         jsonrpc: "mmr_verifyProofStateless",
#         method: "verifyProofStateless",
#         section: "mmr"
#       },
#       "offchain_localStorageGet" => {
#         description: "Get offchain local storage under given key and prefix",
# ...
#     hasSubscriptions: true,
#     rpc: [Function: method] {
#       author: {
#         hasKey: [Getter],
#         hasSessionKeys: [Getter],
#         insertKey: [Getter],
#         pendingExtrinsics: [Getter],
#         removeExtrinsic: [Getter],
#         rotateKeys: [Getter],
#         submitAndWatchExtrinsic: [Getter],
#         submitExtrinsic: [Getter]
#       },
#       babe: { epochAuthorship: [Getter] },
#       beefy: {},
#       chain: {
#         getBlock: [Getter],
#         getBlockHash: [Getter],
#         getFinalizedHead: [Getter],
#         getHeader: [Getter],
#         subscribeAllHeads: [Getter],
#         subscribeFinalizedHeads: [Getter],
#         subscribeNewHeads: [Getter]
#       },
#       childstate: {
#         getKeys: [Getter],
#         getKeysPaged: [Getter],
#         getStorage: [Getter],
#         getStorageEntries: [Getter],
#         getStorageHash: [Getter],
#         getStorageSize: [Getter]
#       },
#       contracts: {},
#       dev: { getBlockStats: [Getter] },
#       engine: {},
#       net: {},
#       web3: {},
#       eth: {},
#       grandpa: {
#         proveFinality: [Getter],
#         roundState: [Getter],
#         subscribeJustifications: [Getter]
#       },
#       mmr: {},
#       offchain: { localStorageGet: [Getter], localStorageSet: [Getter] },
#       payment: { queryFeeDetails: [Getter], queryInfo: [Getter] },
#       rpc: { methods: [Getter] },
#       state: {
#         call: [Getter],
#         getChildReadProof: [Getter],
#         getKeys: [Getter],
#         getKeysPaged: [Getter],
#         getMetadata: [Getter],
#         getPairs: [Getter],
#         getReadProof: [Getter],
#         getRuntimeVersion: [Getter],
#         getStorage: [Getter],
#         getStorageHash: [Getter],
#         getStorageSize: [Getter],
#         queryStorage: [Getter],
#         queryStorageAt: [Getter],
#         subscribeRuntimeVersion: [Getter],
#         subscribeStorage: [Getter],
#         traceBlock: [Getter],
#         trieMigrationStatus: [Getter]
#       },
#       syncstate: { genSyncSpec: [Getter] },
#       system: {
#         accountNextIndex: [Getter],
#         addLogFilter: [Getter],
#         addReservedPeer: [Getter],
#         chain: [Getter],
#         chainType: [Getter],
#         dryRun: [Getter],
#         health: [Getter],
#         localListenAddresses: [Getter],
#         localPeerId: [Getter],
#         name: [Getter],
#         nodeRoles: [Getter],
#         peers: [Getter],
#         properties: [Getter],
#         removeReservedPeer: [Getter],
#         reservedPeers: [Getter],
#         resetLogFilter: [Getter],
#         syncState: [Getter],
#         version: [Getter]
#       },
#       gear: {
#         calculateInitUploadGas: [Getter],
#         calculateInitCreateGas: [Getter],
#         calculateHandleGas: [Getter],
#         calculateReplyGas: [Getter],
#         readMetahash: [Getter],
#         readState: [Getter],
#         readStateUsingWasm: [Getter],
#         readStateBatch: [Getter],
#         readStateUsingWasmBatch: [Getter]
#       },
#       chainSpec_unstable: {
#         chainName: [Getter],
#         properties: [Getter],
#         genesisHash: [Getter]
#       },
#       transaction_unstable: { submitAndWatch: [Getter], unwatch: [Getter] },
#       runtime: { wasmBlobVersion: [Getter] }
#     },
#     queryMulti: [Function (anonymous)],
#     signer: undefined,
#     runtimeVersion: Type(8) [Map] {
#       "specName" => [String (Text): "gear"] {
#         registry: TypeRegistry { createdAtHash: undefined },
#         createdAtHash: undefined,
#         initialU8aLength: 0,
#         isStorageFallback: undefined
#       },
#       "implName" => [String (Text): "gear"] {
#         registry: TypeRegistry { createdAtHash: undefined },
#         createdAtHash: undefined,
#         initialU8aLength: 0,
#         isStorageFallback: undefined
#       },
#       "authoringVersion" => <BN: 1>,
#       "specVersion" => <BN: 3e8>,
#       "implVersion" => <BN: 1>,
#       "apis" => Type(11) [
#         Type(2) [
#           [Type [Uint8Array]],
#           <BN: 2>,
#           registry: [TypeRegistry],
#           createdAtHash: undefined,
#           initialU8aLength: 0,
#           isStorageFallback: undefined
#         ],
#         Type(2) [
#           [Type [Uint8Array]],
#           <BN: 4>,
#           registry: [TypeRegistry],
#           createdAtHash: undefined,
#           initialU8aLength: 0,
#           isStorageFallback: undefined
#         ],
#         Type(2) [
#           [Type [Uint8Array]],
#           <BN: 1>,
#           registry: [TypeRegistry],
#           createdAtHash: undefined,
#           initialU8aLength: 0,
#           isStorageFallback: undefined
#         ],
#         Type(2) [
#           [Type [Uint8Array]],
#           <BN: 6>,
#           registry: [TypeRegistry],
#           createdAtHash: undefined,
#           initialU8aLength: 0,
#           isStorageFallback: undefined
#         ],
#         Type(2) [
#           [Type [Uint8Array]],
#           <BN: 3>,
#           registry: [TypeRegistry],
#           createdAtHash: undefined,
#           initialU8aLength: 0,
#           isStorageFallback: undefined
#         ],
#         Type(2) [
#           [Type [Uint8Array]],
#           <BN: 2>,
#           registry: [TypeRegistry],
#           createdAtHash: undefined,
#           initialU8aLength: 0,
#           isStorageFallback: undefined
#         ],
#         Type(2) [
#           [Type [Uint8Array]],
#           <BN: 1>,
#           registry: [TypeRegistry],
#           createdAtHash: undefined,
#           initialU8aLength: 0,
#           isStorageFallback: undefined
#         ],
#         Type(2) [
#           [Type [Uint8Array]],
#           <BN: 3>,
#           registry: [TypeRegistry],
#           createdAtHash: undefined,
#           initialU8aLength: 0,
#           isStorageFallback: undefined
#         ],
#         Type(2) [
#           [Type [Uint8Array]],
#           <BN: 1>,
#           registry: [TypeRegistry],
#           createdAtHash: undefined,
#           initialU8aLength: 0,
#           isStorageFallback: undefined
#         ],
#         Type(2) [
#           [Type [Uint8Array]],
#           <BN: 3>,
#           registry: [TypeRegistry],
#           createdAtHash: undefined,
#           initialU8aLength: 0,
#           isStorageFallback: undefined
#         ],
#         Type(2) [
#           [Type [Uint8Array]],
#           <BN: 1>,
#           registry: [TypeRegistry],
#           createdAtHash: undefined,
#           initialU8aLength: 0,
#           isStorageFallback: undefined
#         ],
#         registry: TypeRegistry { createdAtHash: undefined },
#         createdAtHash: undefined,
#         initialU8aLength: 0,
#         isStorageFallback: undefined
#       ],
#       "transactionVersion" => <BN: 1>,
#       "stateVersion" => <BN: 1>,
#       registry: TypeRegistry { createdAtHash: undefined },
#       createdAtHash: undefined,
#       initialU8aLength: 0,
#       isStorageFallback: undefined
#     },
#     extrinsicType: 4,
#     genesisHash: Type(32) [Uint8Array] [
#       165,
#       253,
#       202,
#       221,
#       36,
#       131,
#       44,
#       112,
#       144,
#       255,
#       11,
#       11,
#       108,
#       227,
#       125,
#       96,
#       183,
#       202,
#       156,
#       181,
#       76,
#       36,
#       230,
#       186,
#       233,
#       62,
#       42,
#       23,
#       13,
#       99,
#       7,
#       199,
#       registry: TypeRegistry { createdAtHash: undefined },
#       createdAtHash: undefined,
#       initialU8aLength: 32,
#       isStorageFallback: undefined
#     ],
#     derive: {
#       accounts: [Getter],
#       alliance: [Getter],
#       balances: [Getter],
#       bounties: [Getter],
#       chain: {
#         _getHeaderRange: [Getter],
#         bestNumber: [Getter],
#         bestNumberFinalized: [Getter],
#         bestNumberLag: [Getter],
#         getBlock: [Getter],
#         getBlockByNumber: [Getter],
#         getHeader: [Getter],
#         subscribeFinalizedHeads: [Getter],
#         subscribeNewBlocks: [Getter],
#         subscribeNewHeads: [Function: memoized] { unmemoize: [Function (anonymous)] }
#       },
#       session: [Getter],
#       tx: [Getter]
#     }
#   },
#   _options: {
#     provider: WsProvider {},
#     derives: {},
#     types: {
#       MessageId: "[u8;32]",
#       ExitCode: "i32",
#       Payload: "Vec<u8>",
#       TypesRepr: { input: "Option<u32>", output: "Option<u32>" },
#       ProgramMetadataReprRustV1: {
#         init: "TypesRepr",
#         handle: "TypesRepr",
#         reply: "Option<u32>",
#         others: "TypesRepr",
#         signal: "Option<u32>",
#         state: "Option<u32>",
#         reg: "Vec<u8>"
#       },
#       ProgramMetadataReprRustV2: {
#         init: "TypesRepr",
#         handle: "TypesRepr",
#         reply: "Option<u32>",
#         others: "TypesRepr",
#         signal: "Option<u32>",
#         state: "TypesRepr",
#         reg: "Vec<u8>"
#       },
#       StateMetadataRepr: { functions: "BTreeMap<String, TypesRepr>", reg: "Vec<u8>" },
#       ProgramId: "[u8;32]",
#       Program: {
#         _enum: {
#           Active: "ActiveProgram",
#           Exited: "ProgramId",
#           Terminated: "ProgramId"
#         }
#       },
#       WasmPageNumber: "u32",
#       PageNumber: "u32",
#       ReservationId: "[u8;32]",
#       GasReservationSlot: { amount: "u64", start: "u32", finish: "u32" },
#       ActiveProgram: {
#         allocations: "BTreeSet<WasmPageNumber>",
#         pages_with_data: "BTreeSet<PageNumber>",
#         gas_reservation_map: "BTreeMap<ReservationId, GasReservationSlot>",
#         code_hash: "H256",
#         code_length_bytes: "u32",
#         code_exports: "BTreeSet<DispatchKind>",
#         static_pages: "WasmPageNumber",
#         state: "ProgramState",
#         expiration_block: "BlockNumber"
#       },
#       ProgramState: { _enum: { Uninitialized: [Object], Initialized: "Null" } },
#       ExecutionResult: { _enum: { Success: "Null", Failure: "Vec<u8>" } },
#       GasInfo: {
#         min_limit: "u64",
#         reserved: "u64",
#         burned: "u64",
#         may_be_returned: "u64",
#         waited: "bool"
#       },
#       Value: "Compact<u128>",
#       Dispatch: { kind: "DispatchKind", message: "Message" },
#       DispatchKind: { _enum: [ "Init", "Handle", "Reply", "Signal" ] },
#       Reason: {
#         _enum: { Error: "Null", ValueTransfer: "Null", Dispatch: "Vec<u8>" }
#       },
#       DispatchOutcome: { message_id: "H256", outcome: "ExecutionResult" },
#       MessageInfo: { message_id: "H256", program_id: "H256", origin: "H256" },
#       UserStoredMessage: {
#         id: "MessageId",
#         source: "ProgramId",
#         destination: "ProgramId",
#         payload: "Payload",
#         value: "Value"
#       },
#       Interval: { start: "u32", finish: "u32" },
#       ProgramDetails: {
#         id: "H256",
#         static_pages: "u32",
#         persistent_pages: "BTreeMap<u32, Vec<u8>>",
#         code_hash: "H256",
#         nonce: "u64"
#       },
#       DebugData: {
#         dispatch_queue: "Vec<QueuedDispatch>",
#         programs: "Vec<ProgramDetails>"
#       }
#     },
#     rpc: {
#       gear: {
#         calculateInitUploadGas: {
#           description: "Calculate gas for Init message using upload_program extrinsic",
#           params: [Array],
#           type: "GasInfo"
#         },
#         calculateInitCreateGas: {
#           description: "Calculate gas for Init message using create_program extrinsic",
#           params: [Array],
#           type: "GasInfo"
#         },
#         calculateHandleGas: {
#           description: "Calculate gas for Handle message",
#           params: [Array],
#           type: "GasInfo"
#         },
#         calculateReplyGas: {
#           description: "Calculate gas for Reply message",
#           params: [Array],
#           type: "GasInfo"
#         },
#         readMetahash: { params: [Array], type: "H256" },
#         readState: { params: [Array], type: "Bytes" },
#         readStateUsingWasm: { params: [Array], type: "Bytes" },
#         readStateBatch: { params: [Array], type: "Vec<Bytes>" },
#         readStateUsingWasmBatch: { params: [Array], type: "Vec<Bytes>" }
#       },
#       chainSpec_unstable: {
#         chainName: { params: [], type: "String" },
#         properties: { params: [], type: "String" },
#         genesisHash: { params: [], type: "H256" }
#       },
#       transaction_unstable: { submitAndWatch: { params: [] }, unwatch: { params: [] } },
#       runtime: {
#         wasmBlobVersion: {
#           description: "Returns the version of the WASM blob in storage.",
#           params: [],
#           type: "String"
#         }
#       }
#     },
#     runtime: { GearApi: [ { methods: {}, version: 1 } ] }
#   },
#   _decorateMethod: [Function: toPromiseMethod],
#   _rxDecorateMethod: [Function: _rxDecorateMethod],
#   program: GearProgram {
#     _api: [Circular *1],
#     extrinsic: undefined,
#     calculateGas: GearGas { _api: [Circular *1] },
#     resumeSession: GearResumeSession { _api: [Circular *1], extrinsic: undefined }
#   },
#   programState: GearProgramState { _api: [Circular *1] },
#   programStorage: GearProgramStorage { _api: [Circular *1] },
#   message: GearMessage { _api: [Circular *1], extrinsic: undefined },
#   balance: GearBalance { _api: [Circular *1], extrinsic: undefined },
#   gearEvents: GearEvents { api: [Circular *1] },
#   defaultTypes: {
#     MessageId: "[u8;32]",
#     ExitCode: "i32",
#     Payload: "Vec<u8>",
#     TypesRepr: { input: "Option<u32>", output: "Option<u32>" },
#     ProgramMetadataReprRustV1: {
#       init: "TypesRepr",
#       handle: "TypesRepr",
#       reply: "Option<u32>",
#       others: "TypesRepr",
#       signal: "Option<u32>",
#       state: "Option<u32>",
#       reg: "Vec<u8>"
#     },
#     ProgramMetadataReprRustV2: {
#       init: "TypesRepr",
#       handle: "TypesRepr",
#       reply: "Option<u32>",
#       others: "TypesRepr",
#       signal: "Option<u32>",
#       state: "TypesRepr",
#       reg: "Vec<u8>"
#     },
#     StateMetadataRepr: { functions: "BTreeMap<String, TypesRepr>", reg: "Vec<u8>" },
#     ProgramId: "[u8;32]",
#     Program: {
#       _enum: {
#         Active: "ActiveProgram",
#         Exited: "ProgramId",
#         Terminated: "ProgramId"
#       }
#     },
#     WasmPageNumber: "u32",
#     PageNumber: "u32",
#     ReservationId: "[u8;32]",
#     GasReservationSlot: { amount: "u64", start: "u32", finish: "u32" },
#     ActiveProgram: {
#       allocations: "BTreeSet<WasmPageNumber>",
#       pages_with_data: "BTreeSet<PageNumber>",
#       gas_reservation_map: "BTreeMap<ReservationId, GasReservationSlot>",
#       code_hash: "H256",
#       code_length_bytes: "u32",
#       code_exports: "BTreeSet<DispatchKind>",
#       static_pages: "WasmPageNumber",
#       state: "ProgramState",
#       expiration_block: "BlockNumber"
#     },
#     ProgramState: {
#       _enum: {
#         Uninitialized: { message_id: "MessageId" },
#         Initialized: "Null"
#       }
#     },
#     ExecutionResult: { _enum: { Success: "Null", Failure: "Vec<u8>" } },
#     GasInfo: {
#       min_limit: "u64",
#       reserved: "u64",
#       burned: "u64",
#       may_be_returned: "u64",
#       waited: "bool"
#     },
#     Value: "Compact<u128>",
#     Dispatch: { kind: "DispatchKind", message: "Message" },
#     DispatchKind: { _enum: [ "Init", "Handle", "Reply", "Signal" ] },
#     Reason: {
#       _enum: { Error: "Null", ValueTransfer: "Null", Dispatch: "Vec<u8>" }
#     },
#     DispatchOutcome: { message_id: "H256", outcome: "ExecutionResult" },
#     MessageInfo: { message_id: "H256", program_id: "H256", origin: "H256" },
#     UserStoredMessage: {
#       id: "MessageId",
#       source: "ProgramId",
#       destination: "ProgramId",
#       payload: "Payload",
#       value: "Value"
#     },
#     Interval: { start: "u32", finish: "u32" },
#     ProgramDetails: {
#       id: "H256",
#       static_pages: "u32",
#       persistent_pages: "BTreeMap<u32, Vec<u8>>",
#       code_hash: "H256",
#       nonce: "u64"
#     },
#     DebugData: {
#       dispatch_queue: "Vec<QueuedDispatch>",
#       programs: "Vec<ProgramDetails>"
#     }
#   },
#   blocks: GearBlock {
#     api: [Circular *1],
#     subscribeNewHeads: [Function (anonymous)]
#   },
#   mailbox: GearMailbox {
#     api: [Circular *1],
#     claimValue: GearClaimValue { _api: [Circular *1], extrinsic: undefined }
#   },
#   claimValueFromMailbox: GearClaimValue { _api: [Circular *1], extrinsic: undefined },
#   code: GearCode { _api: [Circular *1], extrinsic: undefined },
#   waitlist: GearWaitlist { _api: [Circular *1] },
#   voucher: GearVoucher { _api: [Circular *1], extrinsic: undefined },
#   provider: WsProvider {}
# }
